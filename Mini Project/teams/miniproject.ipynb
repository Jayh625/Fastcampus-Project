# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()

# %matplotlib inline

pd.options.mode.chained_assignment = None  # default='warn'

# %%
data = pd.read_excel("/Users/a33/Desktop/work/fastcampus.xlsx")

# %%
data.head()
# Out:
#        id  customer_id  course_id     type      state  \
# 0  970634     504760.0   201435.0    ORDER  CANCELLED
# 1  970650     432862.0   203178.0    ORDER  CANCELLED
# 2  970657      72297.0   204246.0  PAYMENT  COMPLETED
# 3  970656      72297.0   204246.0    ORDER  CANCELLED
# 4  970658     478028.0   201797.0  PAYMENT  COMPLETED
#
#                     course_title category_title  format        completed_at  \
# 0      올인원 패키지 : 알고리즘 기술면접 완전 정복          프로그래밍     올인원 2021-03-28 15:00:11
# 1    초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D     올인원 2021-03-28 15:16:53
# 2           시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인 2021-03-28 15:21:43
# 3           시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인 2021-03-28 15:21:43
# 4  올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX         업무 생산성     올인원 2021-03-28 15:21:54
#
#    transaction_amount              coupon_title  coupon_discount_amount  \
# 0               90500                       NaN                     NaN
# ...

# %%
category_values = data['category_title'].value_counts()
category_labels = data['category_title'].unique().tolist()
print(category_values)
print(category_labels)
# Out:
# 프로그래밍       34430
# 데이터사이언스     14076
# 업무 생산성      13323
# 디자인         12009
# 영상/3D       10260
# 마케팅          9857
# 부동산/금융       5523
# 투자/재테크       2501
# 크리에이티브       2250
# 교육           1031
# 지식콘텐츠          56
# 비즈니스           42
# 파이낸스           25
# 데이터 사이언스        9
# 관리              2
# 일러스트            1
# Name: category_title, dtype: int64
# ['프로그래밍', '영상/3D', '업무 생산성', '크리에이티브', '부동산/금융', '데이터사이언스', '디자인', '마케팅', '교육', '투자/재테크', nan, '관리', '데이터 사이언스', '비즈니스', '지식콘텐츠', '일러스트', '파이낸스']

# %%
format_values = data['format'].value_counts()
format_labels = data['format'].unique().tolist()
print(format_values)
print(format_labels)
# Out:
# 올인원        87402
# RED         6253
# 온라인 완주반     3817
# 하루10분컷      2978
# B2B 온라인     1086
# 스쿨 온라인      1057
# 스쿨          1036
# B2B          808
# B2G          592
# 이벤트          193
# 아카이브          72
# MBA           56
# 캠프            48
# 관리             2
# 콜로소            2
# 온라인            1
# Name: format, dtype: int64
# ['올인원', '스쿨 온라인', '온라인 완주반', 'RED', 'B2B 온라인', '캠프', '스쿨', nan, 'B2B', '이벤트', '하루10분컷', '아카이브', '관리', '온라인', 'MBA', '콜로소', 'B2G']

# %%
type_values = data['type'].value_counts()
type_labels = data['type'].unique().tolist()
print(type_values)
print(type_labels)
# Out:
# PAYMENT        61433
# ORDER          40159
# REFUND          3824
# TRANSACTION        3
# Name: type, dtype: int64
# ['ORDER', 'PAYMENT', 'REFUND', 'TRANSACTION']

# %%
state_values = data['state'].value_counts()
state_labels = data['state'].unique().tolist()
print(state_values)
print(state_labels)
# Out:
# COMPLETED    62763
# CANCELLED    41279
# PENDING       1144
# DELETED        219
# REQUESTED       14
# Name: state, dtype: int64
# ['CANCELLED', 'COMPLETED', 'PENDING', 'DELETED', 'REQUESTED']
